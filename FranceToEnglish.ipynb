# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'fra.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-france.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-france.pkl
# [go] => [va]
# [hi] => [salut]
# [hi] => [salut]
# [run] => [cours]
# [run] => [courez]
# [who] => [qui]
# [wow] => [ca alors]
# [fire] => [au feu]
# [help] => [a laide]
# [jump] => [saute]
# [stop] => [ca suffit]
# [stop] => [stop]
# [stop] => [arretetoi]
# [wait] => [attends]
# [wait] => [attendez]
# [go on] => [poursuis]
# [go on] => [continuez]
# [go on] => [poursuivez]
# [hello] => [bonjour]
# [hello] => [salut]
# [i see] => [je comprends]
# [i try] => [jessaye]
# [i won] => [jai gagne]
# [i won] => [je lai emporte]
# [i won] => [jai gagne]
# [oh no] => [oh non]
# [attack] => [attaque]
# [attack] => [attaquez]
# [cheers] => [sante]
# [cheers] => [a votre sante]
# [cheers] => [merci]
# [cheers] => [tchintchin]
# [get up] => [levetoi]
# [go now] => [va maintenant]
# [go now] => [allezy maintenant]
# [go now] => [vasy maintenant]
# [got it] => [jai pige]
# [got it] => [compris]
# [got it] => [pige]
# [got it] => [compris]
# [got it] => [tas capte]
# [hop in] => [monte]
# [hop in] => [montez]
# [hug me] => [serremoi dans tes bras]
# [hug me] => [serrezmoi dans vos bras]
# [i fell] => [je suis tombee]
# [i fell] => [je suis tombe]
# [i fled] => [jai fui]
# [i know] => [je sais]
# [i left] => [je suis parti]
# [i left] => [je suis partie]
# [i lied] => [jai menti]
# [i lost] => [jai perdu]
# [i paid] => [jai paye]
# [im] => [jai ans]
# [im ok] => [je vais bien]
# [im ok] => [ca va]
# [listen] => [ecoutez]
# [no way] => [cest pas possible]
# [no way] => [impossible]
# [no way] => [en aucun cas]
# [no way] => [sans facons]
# [no way] => [cest hors de question]
# [no way] => [il nen est pas question]
# [no way] => [cest exclu]
# [no way] => [en aucune maniere]
# [no way] => [hors de question]
# [really] => [vraiment]
# [really] => [vrai]
# [really] => [ah bon]
# [thanks] => [merci]
# [thanks] => [merci]
# [we try] => [on essaye]
# [we won] => [nous avons gagne]
# [we won] => [nous gagnames]
# [we won] => [nous lavons emporte]
# [we won] => [nous lemportames]
# [ask tom] => [demande a tom]
# [awesome] => [fantastique]
# [be calm] => [sois calme]
# [be calm] => [soyez calme]
# [be calm] => [soyez calmes]
# [be cool] => [sois detendu]
# [be fair] => [sois juste]
# [be fair] => [soyez juste]
# [be fair] => [soyez justes]
# [be fair] => [sois equitable]
# [be fair] => [soyez equitable]
# [be fair] => [soyez equitables]
# [be kind] => [sois gentil]
# [be nice] => [sois gentil]
# [be nice] => [sois gentille]
# [be nice] => [soyez gentil]
# [be nice] => [soyez gentille]
# [be nice] => [soyez gentils]
# [be nice] => [soyez gentilles]
# [beat it] => [degage]
# [call me] => [appellemoi]
# [call me] => [appelezmoi]
# [call us] => [appellenous]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-france.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-france-both.pkl')
save_clean_data(train, 'english-france-train.pkl')
save_clean_data(test, 'english-france-test.pkl')
# Out:
# Saved: english-france-both.pkl
# Saved: english-france-train.pkl
# Saved: english-france-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-france-both.pkl')
train = load_clean_sentences('english-france-train.pkl')
test = load_clean_sentences('english-france-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('France Vocabulary Size: %d' % ger_vocab_size)
print('France Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2158
# English Max Length: 5
# France Vocabulary Size: 4388
# France Max Length: 10
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 10, 256)           1123328
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 5, 256)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 5, 2158)           554606
# =================================================================
# Total params: 2,728,558
# Trainable params: 2,728,558
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 39s - loss: 4.1989 - val_loss: 3.3442
#
# Epoch 00001: val_loss improved from inf to 3.34418, saving model to model.h5
# Epoch 2/100
# 141/141 - 31s - loss: 3.2402 - val_loss: 3.1192
#
# Epoch 00002: val_loss improved from 3.34418 to 3.11924, saving model to model.h5
# Epoch 3/100
# 141/141 - 30s - loss: 3.0680 - val_loss: 2.9734
#
# Epoch 00003: val_loss improved from 3.11924 to 2.97343, saving model to model.h5
# Epoch 4/100
# 141/141 - 30s - loss: 2.9304 - val_loss: 2.8227
#
# Epoch 00004: val_loss improved from 2.97343 to 2.82273, saving model to model.h5
# Epoch 5/100
# 141/141 - 30s - loss: 2.7669 - val_loss: 2.6874
#
# Epoch 00005: val_loss improved from 2.82273 to 2.68735, saving model to model.h5
# Epoch 6/100
# 141/141 - 30s - loss: 2.6074 - val_loss: 2.5065
#
# Epoch 00006: val_loss improved from 2.68735 to 2.50652, saving model to model.h5
# Epoch 7/100
# 141/141 - 30s - loss: 2.4567 - val_loss: 2.3650
#
# Epoch 00007: val_loss improved from 2.50652 to 2.36495, saving model to model.h5
# Epoch 8/100
# 141/141 - 30s - loss: 2.3184 - val_loss: 2.2420
#
# Epoch 00008: val_loss improved from 2.36495 to 2.24198, saving model to model.h5
# Epoch 9/100
# 141/141 - 30s - loss: 2.1837 - val_loss: 2.1209
#
# Epoch 00009: val_loss improved from 2.24198 to 2.12089, saving model to model.h5
# Epoch 10/100
# 141/141 - 30s - loss: 2.0629 - val_loss: 1.9952
#
# Epoch 00010: val_loss improved from 2.12089 to 1.99516, saving model to model.h5
# Epoch 11/100
# 141/141 - 30s - loss: 1.9318 - val_loss: 1.8729
#
# Epoch 00011: val_loss improved from 1.99516 to 1.87289, saving model to model.h5
# Epoch 12/100
# 141/141 - 30s - loss: 1.8069 - val_loss: 1.7537
#
# Epoch 00012: val_loss improved from 1.87289 to 1.75374, saving model to model.h5
# Epoch 13/100
# 141/141 - 30s - loss: 1.6882 - val_loss: 1.6534
#
# Epoch 00013: val_loss improved from 1.75374 to 1.65345, saving model to model.h5
# Epoch 14/100
# 141/141 - 30s - loss: 1.5815 - val_loss: 1.5573
#
# Epoch 00014: val_loss improved from 1.65345 to 1.55732, saving model to model.h5
# Epoch 15/100
# 141/141 - 30s - loss: 1.4759 - val_loss: 1.4580
#
# Epoch 00015: val_loss improved from 1.55732 to 1.45801, saving model to model.h5
# Epoch 16/100
# 141/141 - 31s - loss: 1.3748 - val_loss: 1.3616
#
# Epoch 00016: val_loss improved from 1.45801 to 1.36163, saving model to model.h5
# Epoch 17/100
# 141/141 - 30s - loss: 1.2825 - val_loss: 1.2768
#
# Epoch 00017: val_loss improved from 1.36163 to 1.27677, saving model to model.h5
# Epoch 18/100
# 141/141 - 30s - loss: 1.1893 - val_loss: 1.1927
#
# Epoch 00018: val_loss improved from 1.27677 to 1.19266, saving model to model.h5
# Epoch 19/100
# 141/141 - 30s - loss: 1.0996 - val_loss: 1.1159
#
# Epoch 00019: val_loss improved from 1.19266 to 1.11591, saving model to model.h5
# Epoch 20/100
# 141/141 - 30s - loss: 1.0155 - val_loss: 1.0397
#
# Epoch 00020: val_loss improved from 1.11591 to 1.03973, saving model to model.h5
# Epoch 21/100
# 141/141 - 30s - loss: 0.9359 - val_loss: 0.9713
#
# Epoch 00021: val_loss improved from 1.03973 to 0.97130, saving model to model.h5
# Epoch 22/100
# 141/141 - 30s - loss: 0.8637 - val_loss: 0.9117
#
# Epoch 00022: val_loss improved from 0.97130 to 0.91170, saving model to model.h5
# Epoch 23/100
# 141/141 - 31s - loss: 0.7931 - val_loss: 0.8468
#
# Epoch 00023: val_loss improved from 0.91170 to 0.84683, saving model to model.h5
# Epoch 24/100
# 141/141 - 30s - loss: 0.7278 - val_loss: 0.7882
#
# Epoch 00024: val_loss improved from 0.84683 to 0.78822, saving model to model.h5
# Epoch 25/100
# 141/141 - 30s - loss: 0.6646 - val_loss: 0.7404
#
# Epoch 00025: val_loss improved from 0.78822 to 0.74042, saving model to model.h5
# Epoch 26/100
# 141/141 - 30s - loss: 0.6091 - val_loss: 0.6942
#
# Epoch 00026: val_loss improved from 0.74042 to 0.69420, saving model to model.h5
# Epoch 27/100
# 141/141 - 30s - loss: 0.5594 - val_loss: 0.6517
#
# Epoch 00027: val_loss improved from 0.69420 to 0.65169, saving model to model.h5
# Epoch 28/100
# 141/141 - 30s - loss: 0.5111 - val_loss: 0.6088
#
# Epoch 00028: val_loss improved from 0.65169 to 0.60882, saving model to model.h5
# Epoch 29/100
# 141/141 - 30s - loss: 0.4686 - val_loss: 0.5789
#
# Epoch 00029: val_loss improved from 0.60882 to 0.57891, saving model to model.h5
# Epoch 30/100
# 141/141 - 29s - loss: 0.4279 - val_loss: 0.5488
#
# Epoch 00030: val_loss improved from 0.57891 to 0.54876, saving model to model.h5
# Epoch 31/100
# 141/141 - 30s - loss: 0.3927 - val_loss: 0.5196
#
# Epoch 00031: val_loss improved from 0.54876 to 0.51964, saving model to model.h5
# Epoch 32/100
# 141/141 - 30s - loss: 0.3619 - val_loss: 0.4935
#
# Epoch 00032: val_loss improved from 0.51964 to 0.49350, saving model to model.h5
# Epoch 33/100
# 141/141 - 30s - loss: 0.3330 - val_loss: 0.4694
#
# Epoch 00033: val_loss improved from 0.49350 to 0.46942, saving model to model.h5
# Epoch 34/100
# 141/141 - 30s - loss: 0.3061 - val_loss: 0.4518
#
# Epoch 00034: val_loss improved from 0.46942 to 0.45178, saving model to model.h5
# Epoch 35/100
# 141/141 - 30s - loss: 0.2823 - val_loss: 0.4341
#
# Epoch 00035: val_loss improved from 0.45178 to 0.43414, saving model to model.h5
# Epoch 36/100
# 141/141 - 30s - loss: 0.2608 - val_loss: 0.4196
#
# Epoch 00036: val_loss improved from 0.43414 to 0.41960, saving model to model.h5
# Epoch 37/100
# 141/141 - 30s - loss: 0.2410 - val_loss: 0.4060
#
# Epoch 00037: val_loss improved from 0.41960 to 0.40604, saving model to model.h5
# Epoch 38/100
# 141/141 - 30s - loss: 0.2251 - val_loss: 0.3931
#
# Epoch 00038: val_loss improved from 0.40604 to 0.39307, saving model to model.h5
# Epoch 39/100
# 141/141 - 29s - loss: 0.2084 - val_loss: 0.3818
#
# Epoch 00039: val_loss improved from 0.39307 to 0.38178, saving model to model.h5
# Epoch 40/100
# 141/141 - 29s - loss: 0.1974 - val_loss: 0.3711
#
# Epoch 00040: val_loss improved from 0.38178 to 0.37109, saving model to model.h5
# Epoch 41/100
# 141/141 - 29s - loss: 0.1857 - val_loss: 0.3620
#
# Epoch 00041: val_loss improved from 0.37109 to 0.36199, saving model to model.h5
# Epoch 42/100
# 141/141 - 29s - loss: 0.1748 - val_loss: 0.3603
#
# Epoch 00042: val_loss improved from 0.36199 to 0.36026, saving model to model.h5
# Epoch 43/100
# 141/141 - 30s - loss: 0.1676 - val_loss: 0.3492
#
# Epoch 00043: val_loss improved from 0.36026 to 0.34922, saving model to model.h5
# Epoch 44/100
# 141/141 - 30s - loss: 0.1565 - val_loss: 0.3445
#
# Epoch 00044: val_loss improved from 0.34922 to 0.34454, saving model to model.h5
# Epoch 45/100
# 141/141 - 30s - loss: 0.1495 - val_loss: 0.3390
#
# Epoch 00045: val_loss improved from 0.34454 to 0.33904, saving model to model.h5
# Epoch 46/100
# 141/141 - 29s - loss: 0.1424 - val_loss: 0.3349
#
# Epoch 00046: val_loss improved from 0.33904 to 0.33486, saving model to model.h5
# Epoch 47/100
# 141/141 - 29s - loss: 0.1348 - val_loss: 0.3312
#
# Epoch 00047: val_loss improved from 0.33486 to 0.33122, saving model to model.h5
# Epoch 48/100
# 141/141 - 30s - loss: 0.1312 - val_loss: 0.3313
#
# Epoch 00048: val_loss did not improve from 0.33122
# Epoch 49/100
# 141/141 - 29s - loss: 0.1270 - val_loss: 0.3236
#
# Epoch 00049: val_loss improved from 0.33122 to 0.32358, saving model to model.h5
# Epoch 50/100
# 141/141 - 29s - loss: 0.1219 - val_loss: 0.3229
#
# Epoch 00050: val_loss improved from 0.32358 to 0.32293, saving model to model.h5
# Epoch 51/100
# 141/141 - 29s - loss: 0.1171 - val_loss: 0.3199
#
# Epoch 00051: val_loss improved from 0.32293 to 0.31985, saving model to model.h5
# Epoch 52/100
# 141/141 - 29s - loss: 0.1133 - val_loss: 0.3178
#
# Epoch 00052: val_loss improved from 0.31985 to 0.31783, saving model to model.h5
# Epoch 53/100
# 141/141 - 29s - loss: 0.1118 - val_loss: 0.3176
#
# Epoch 00053: val_loss improved from 0.31783 to 0.31755, saving model to model.h5
# Epoch 54/100
# 141/141 - 30s - loss: 0.1084 - val_loss: 0.3154
#
# Epoch 00054: val_loss improved from 0.31755 to 0.31542, saving model to model.h5
# Epoch 55/100
# 141/141 - 29s - loss: 0.1068 - val_loss: 0.3135
#
# Epoch 00055: val_loss improved from 0.31542 to 0.31355, saving model to model.h5
# Epoch 56/100
# 141/141 - 30s - loss: 0.1042 - val_loss: 0.3112
#
# Epoch 00056: val_loss improved from 0.31355 to 0.31123, saving model to model.h5
# Epoch 57/100
# 141/141 - 29s - loss: 0.1009 - val_loss: 0.3107
#
# Epoch 00057: val_loss improved from 0.31123 to 0.31070, saving model to model.h5
# Epoch 58/100
# 141/141 - 30s - loss: 0.0995 - val_loss: 0.3116
#
# Epoch 00058: val_loss did not improve from 0.31070
# Epoch 59/100
# 141/141 - 30s - loss: 0.0993 - val_loss: 0.3101
#
# Epoch 00059: val_loss improved from 0.31070 to 0.31014, saving model to model.h5
# Epoch 60/100
# 141/141 - 30s - loss: 0.0966 - val_loss: 0.3107
#
# Epoch 00060: val_loss did not improve from 0.31014
# Epoch 61/100
# 141/141 - 30s - loss: 0.0952 - val_loss: 0.3092
#
# Epoch 00061: val_loss improved from 0.31014 to 0.30922, saving model to model.h5
# Epoch 62/100
# 141/141 - 30s - loss: 0.0942 - val_loss: 0.3094
#
# Epoch 00062: val_loss did not improve from 0.30922
# Epoch 63/100
# 141/141 - 30s - loss: 0.0940 - val_loss: 0.3086
#
# Epoch 00063: val_loss improved from 0.30922 to 0.30864, saving model to model.h5
# Epoch 64/100
# 141/141 - 30s - loss: 0.0917 - val_loss: 0.3068
#
# Epoch 00064: val_loss improved from 0.30864 to 0.30683, saving model to model.h5
# Epoch 65/100
# 141/141 - 30s - loss: 0.0902 - val_loss: 0.3076
#
# Epoch 00065: val_loss did not improve from 0.30683
# Epoch 66/100
# 141/141 - 29s - loss: 0.0887 - val_loss: 0.3092
#
# Epoch 00066: val_loss did not improve from 0.30683
# Epoch 67/100
# 141/141 - 29s - loss: 0.0883 - val_loss: 0.3075
#
# Epoch 00067: val_loss did not improve from 0.30683
# Epoch 68/100
# 141/141 - 30s - loss: 0.0868 - val_loss: 0.3061
#
# Epoch 00068: val_loss improved from 0.30683 to 0.30608, saving model to model.h5
# Epoch 69/100
# 141/141 - 30s - loss: 0.0856 - val_loss: 0.3051
#
# Epoch 00069: val_loss improved from 0.30608 to 0.30506, saving model to model.h5
# Epoch 70/100
# 141/141 - 31s - loss: 0.0845 - val_loss: 0.3077
#
# Epoch 00070: val_loss did not improve from 0.30506
# Epoch 71/100
# 141/141 - 30s - loss: 0.0848 - val_loss: 0.3081
#
# Epoch 00071: val_loss did not improve from 0.30506
# Epoch 72/100
# 141/141 - 30s - loss: 0.0831 - val_loss: 0.3093
#
# Epoch 00072: val_loss did not improve from 0.30506
# Epoch 73/100
# 141/141 - 30s - loss: 0.0832 - val_loss: 0.3091
#
# Epoch 00073: val_loss did not improve from 0.30506
# Epoch 74/100
# 141/141 - 30s - loss: 0.0832 - val_loss: 0.3070
#
# Epoch 00074: val_loss did not improve from 0.30506
# Epoch 75/100
# 141/141 - 30s - loss: 0.0826 - val_loss: 0.3070
#
# Epoch 00075: val_loss did not improve from 0.30506
# Epoch 76/100
# 141/141 - 30s - loss: 0.0824 - val_loss: 0.3091
#
# Epoch 00076: val_loss did not improve from 0.30506
# Epoch 77/100
# 141/141 - 30s - loss: 0.0833 - val_loss: 0.3108
#
# Epoch 00077: val_loss did not improve from 0.30506
# Epoch 78/100
# 141/141 - 30s - loss: 0.0831 - val_loss: 0.3098
#
# Epoch 00078: val_loss did not improve from 0.30506
# Epoch 79/100
# 141/141 - 30s - loss: 0.0834 - val_loss: 0.3111
#
# Epoch 00079: val_loss did not improve from 0.30506
# Epoch 80/100
# 141/141 - 31s - loss: 0.0836 - val_loss: 0.3101
#
# Epoch 00080: val_loss did not improve from 0.30506
# Epoch 81/100
# 141/141 - 30s - loss: 0.0815 - val_loss: 0.3090
#
# Epoch 00081: val_loss did not improve from 0.30506
# Epoch 82/100
# 141/141 - 30s - loss: 0.0808 - val_loss: 0.3102
#
# Epoch 00082: val_loss did not improve from 0.30506
# Epoch 83/100
# 141/141 - 30s - loss: 0.0793 - val_loss: 0.3104
#
# Epoch 00083: val_loss did not improve from 0.30506
# Epoch 84/100
# 141/141 - 30s - loss: 0.0779 - val_loss: 0.3096
#
# Epoch 00084: val_loss did not improve from 0.30506
# Epoch 85/100
# 141/141 - 30s - loss: 0.0772 - val_loss: 0.3086
#
# Epoch 00085: val_loss did not improve from 0.30506
# Epoch 86/100
# 141/141 - 30s - loss: 0.0770 - val_loss: 0.3096
#
# Epoch 00086: val_loss did not improve from 0.30506
# Epoch 87/100
# 141/141 - 30s - loss: 0.0772 - val_loss: 0.3094
#
# Epoch 00087: val_loss did not improve from 0.30506
# Epoch 88/100
# 141/141 - 30s - loss: 0.0766 - val_loss: 0.3122
#
# Epoch 00088: val_loss did not improve from 0.30506
# Epoch 89/100
# 141/141 - 30s - loss: 0.0764 - val_loss: 0.3106
#
# Epoch 00089: val_loss did not improve from 0.30506
# Epoch 90/100
# 141/141 - 30s - loss: 0.0758 - val_loss: 0.3118
#
# Epoch 00090: val_loss did not improve from 0.30506
# Epoch 91/100
# 141/141 - 31s - loss: 0.0758 - val_loss: 0.3112
#
# Epoch 00091: val_loss did not improve from 0.30506
# Epoch 92/100
# 141/141 - 30s - loss: 0.0760 - val_loss: 0.3121
#
# Epoch 00092: val_loss did not improve from 0.30506
# Epoch 93/100
# 141/141 - 30s - loss: 0.0753 - val_loss: 0.3115
#
# Epoch 00093: val_loss did not improve from 0.30506
# Epoch 94/100
# 141/141 - 30s - loss: 0.0743 - val_loss: 0.3113
#
# Epoch 00094: val_loss did not improve from 0.30506
# Epoch 95/100
# 141/141 - 30s - loss: 0.0748 - val_loss: 0.3114
#
# Epoch 00095: val_loss did not improve from 0.30506
# Epoch 96/100
# 141/141 - 30s - loss: 0.0740 - val_loss: 0.3119
#
# Epoch 00096: val_loss did not improve from 0.30506
# Epoch 97/100
# 141/141 - 30s - loss: 0.0744 - val_loss: 0.3135
#
# Epoch 00097: val_loss did not improve from 0.30506
# Epoch 98/100
# 141/141 - 30s - loss: 0.0745 - val_loss: 0.3139
#
# Epoch 00098: val_loss did not improve from 0.30506
# Epoch 99/100
# 141/141 - 30s - loss: 0.0753 - val_loss: 0.3178
#
# Epoch 00099: val_loss did not improve from 0.30506
# Epoch 100/100
# 141/141 - 30s - loss: 0.0754 - val_loss: 0.3157
#
# Epoch 00100: val_loss did not improve from 0.30506

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,train = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-france-both.pkl')
train = load_clean_sentences('english-france-train.pkl')
test = load_clean_sentences('english-france-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[jaime tom], target=[i like tom], predicted=[i like tom]
# src=[il y a un risque], target=[theres a risk], predicted=[theres a risk]
# src=[vous navez qua lignorer], target=[just ignore it], predicted=[just ignore it]
# src=[tu travailles dur], target=[you work hard], predicted=[you work hard]
# src=[cest un phenomene de mode], target=[its a fad], predicted=[its a fad]
# src=[tom nest pas grossier], target=[tom isnt rude], predicted=[tom isnt rude]
# src=[je ne peux pas gagner], target=[i cant win], predicted=[i cant win]
# src=[nous sommes fatiguees], target=[were tired], predicted=[were tired]
# src=[jai dit merci], target=[i said thanks], predicted=[i said thanks]
# src=[asseyezvous a cote de moi], target=[sit beside me], predicted=[sit beside me]
# BLEU-1: 0.951325
# BLEU-2: 0.935680
# BLEU-3: 0.844407
# BLEU-4: 0.515646
# test
# src=[etesvous aveugle], target=[are you blind], predicted=[are you blind]
# src=[je suis ruine], target=[im ruined], predicted=[im ruined]
# src=[vous etes saufs], target=[youre safe], predicted=[youre safe]
# src=[elle lapprecia], target=[she liked that], predicted=[she liked that]
# src=[qui la casse], target=[who broke it], predicted=[who broke it]
# src=[aidemoi a sortir], target=[help me out], predicted=[help me out]
# src=[cest drole], target=[thats funny], predicted=[its funny]
# src=[je suis touriste], target=[im a tourist], predicted=[im a tourist]
# src=[estce quil y a des enfants], target=[are there kids], predicted=[are there kids]
# src=[il pue], target=[he smells bad], predicted=[he smells bad]
# BLEU-1: 0.910023
# BLEU-2: 0.885966
# BLEU-3: 0.797667
# BLEU-4: 0.478799
